# %% [markdown]
# <a href="https://colab.research.google.com/github/liliandayanacruz/YoloMacroinvertebrates/blob/main/YoloTrain-31-03-24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch==1.1
# Out:
# ERROR: Could not find a version that satisfies the requirement torch==1.1 (from versions: 1.11.0, 1.12.0, 1.12.1, 1.13.0, 1.13.1, 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2, 2.2.0, 2.2.1, 2.2.2)
# ERROR: No matching distribution found for torch==1.1

# %%
# !pip install torchvision==0.3
# Out:
# ERROR: Could not find a version that satisfies the requirement torchvision==0.3 (from versions: 0.1.6, 0.1.7, 0.1.8, 0.1.9, 0.2.0, 0.2.1, 0.2.2, 0.2.2.post2, 0.2.2.post3, 0.12.0, 0.13.0, 0.13.1, 0.14.0, 0.14.1, 0.15.0, 0.15.1, 0.15.2, 0.16.0, 0.16.1, 0.16.2, 0.17.0, 0.17.1)
# ERROR: No matching distribution found for torchvision==0.3

# %%
import torch
import torchvision

# %%
import matplotlib as plt
import numpy as np
import tensorboard
from PIL import Image
import tqdm

# %%
print("Versión de PyTorch instalada:", torch.__version__)
print("Version de Torchvision", torchvision.__version__)
# Out:
# Versión de PyTorch instalada: 2.2.1+cu121
# Version de Torchvision 0.17.1+cu121

# %%
# !git clone https://github.com/liliandayanacruz/YoloMacroinvertebrates.git
# Out:
# fatal: destination path 'YoloMacroinvertebrates' already exists and is not an empty directory.

# %%
cd YoloMacroinvertebrates/
# Out:
# /content/YoloMacroinvertebrates

# %%
import urllib.request

# %%
urllib.request.urlretrieve('https://pjreddie.com/media/files/darknet53.conv.74','/content/YoloMacroinvertebrates/weights/darknet53.conv.74')
# Out:
# ('/content/YoloMacroinvertebrates/weights/darknet53.conv.74',
#  <http.client.HTTPMessage at 0x7da87a3db340>)

# %%
# !cp -r "/content/drive/MyDrive/2024-1/YoloMacroinvertebrates/TrainData/custom" "/content/YoloMacroinvertebrates/data"
# !cp -r "/content/drive/MyDrive/2024-1/YoloMacroinvertebrates/TrainData/config" "/content/YoloMacroinvertebrates"

# %%
# !pip install terminaltables

# %%
# !python train.py --model_def config/yolov3-custom5C.cfg --data_config config/custom.data --epochs 200 --batch_size 4 --pretrained_weights weights/darknet53.conv.74
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# | loss       | 0.489219     | 0.480729     | 0.476024     |
# | x          | 0.024901     | 0.027969     | 0.044606     |
# | y          | 0.042370     | 0.055980     | 0.084536     |
# | w          | 0.024289     | 0.026472     | 0.017512     |
# | h          | 0.065411     | 0.019309     | 0.020127     |
# | conf       | 0.329330     | 0.346283     | 0.307676     |
# | cls        | 0.002919     | 0.004715     | 0.001567     |
# | cls_acc    | 100.00%      | 100.00%      | 100.00%      |
# | recall50   | 0.900000     | 0.900000     | 0.950000     |
# | recall75   | 0.550000     | 0.650000     | 0.750000     |
# | precision  | 0.900000     | 0.782609     | 0.452381     |
# | conf_obj   | 0.910088     | 0.870490     | 0.923680     |
# | conf_noobj | 0.001506     | 0.001085     | 0.001096     |
# +------------+--------------+--------------+--------------+
# Total loss 1.4459718465805054
# ---- ETA 0:00:04.700230
#
# ...
